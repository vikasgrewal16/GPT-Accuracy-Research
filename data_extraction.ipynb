# %%
pip install praw
# Out:
# Collecting praw
#   Downloading praw-7.7.1-py3-none-any.whl (191 kB)
#      ------------------------------------ 191.0/191.0 kB 399.0 kB/s eta 0:00:00
# Collecting prawcore<3,>=2.1 (from praw)
#   Downloading prawcore-2.3.0-py3-none-any.whl (16 kB)
# Collecting update-checker>=0.18 (from praw)
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Collecting websocket-client>=0.54.0 (from praw)
#   Downloading websocket_client-1.6.1-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.9/56.9 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0,>=2.6.0 in c:\users\raj vardhan tomar\appdata\local\programs\python\python310\lib\site-packages (from prawcore<3,>=2.1->praw) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\raj vardhan tomar\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.1->praw) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raj vardhan tomar\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.1->praw) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\raj vardhan tomar\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.1->praw) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raj vardhan tomar\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.1->praw) (2022.12.7)
# Installing collected packages: websocket-client, update-checker, prawcore, praw
# Successfully installed praw-7.7.1 prawcore-2.3.0 update-checker-0.18.0 websocket-client-1.6.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import praw
import csv
import time

# %%
from secret import reddit, reddit_secret, youtube_api

# %%
reddit = praw.Reddit(
    client_id=reddit,
    client_secret=reddit_secret,
    user_agent="Infinite_Clock467",
    redirect_uri="http://localhost",
)

# %%
search_query = "GPT reliability"
num_posts_to_fetch = 100  # You can adjust this value to fetch more posts

# Fetch the posts using the search query
posts = reddit.subreddit("all").search(search_query, limit=num_posts_to_fetch)

# Prepare the data for CSV
data = []
for post in posts:
    post_title = post.title
    post_url = post.url

    # Fetch comments from the post
    while True:
        try:
            post.comments.replace_more(limit=None)
            break  # Exit the loop if comments are successfully fetched
        except praw.exceptions.PRAWException as e:
            if isinstance(e, praw.exceptions.TooManyRequests):
                # Handle rate limiting by waiting for the specified time
                retry_after = int(e.response.headers['Retry-After'])
                print(f"Rate limit exceeded. Waiting for {retry_after} seconds...")
                time.sleep(retry_after)
            else:
                print(f"An error occurred: {str(e)}")
                break
    
    for comment in post.comments.list():
        comment_body = comment.body
        data.append([post_title, post_url, comment_body])

# Write data to a CSV file
csv_filename = "reddit_gpt_comments3.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(["Post Title", "Post URL", "Comment"])
    csv_writer.writerows(data)

print(f"Posts and comments related to 'GPT' saved to '{csv_filename}'.")
# Out:
# Posts and comments related to 'GPT' saved to 'reddit_gpt_comments3.csv'.

# %%
import os
import googleapiclient.discovery
from google.oauth2 import service_account

# %%
# Set your API key or service account credentials
API_KEY = youtube_api

# Initialize the YouTube Data API client
if os.path.isfile(API_KEY):
    # If using a service account credentials file
    credentials = service_account.Credentials.from_service_account_file(API_KEY, scopes=["https://www.googleapis.com/auth/youtube.force-ssl"])
    youtube = googleapiclient.discovery.build('youtube', 'v3', credentials=credentials)
else:
    # If using an API key
    youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=API_KEY)

# %%
search_query = 'GPT'

# Variables to keep track of comments and videos
comments = []
video_count = 0
next_page_token = None

# Continue fetching videos and comments until 1000 comments are collected or no more videos are available
while video_count < 1000:
    # Perform a search for videos related to the query
    search_response = youtube.search().list(
        q=search_query,
        type='video',
        maxResults=50,  # Adjust the number of results per page
        pageToken=next_page_token if next_page_token else '',
        part='id'  # Only fetch video IDs to save quota
    ).execute()

    video_ids = [item['id']['videoId'] for item in search_response['items']]
    
    # Fetch comments from the videos
    for video_id in video_ids:
        # Check if comments are disabled for this video
        video_details = youtube.videos().list(part='snippet', id=video_id).execute()
        if 'items' in video_details and 'snippet' in video_details['items'][0]:
            snippet = video_details['items'][0]['snippet']
            if 'commentsDisabled' in snippet and snippet['commentsDisabled']:
                print(f'Comments are disabled for video {video_id}. Skipping...')
                continue
        
        # Fetch comments from the videos
    for video_id in video_ids:
        try:
            # Fetch comments from the video
            video_comments = []
            video_next_page_token = None

            while True:
                comment_request = youtube.commentThreads().list(
                    part='snippet',
                    videoId=video_id,
                    maxResults=100,  # Adjust the number of comments per page
                    pageToken=video_next_page_token if video_next_page_token else ''
                )

                comment_response = comment_request.execute()

                for comment in comment_response['items']:
                    comment_text = comment['snippet']['topLevelComment']['snippet']['textDisplay']
                    video_comments.append(comment_text)
                    comments.append(comment_text)

                video_next_page_token = comment_response.get('nextPageToken')

                if not video_next_page_token:
                    break

            video_count += 1
            print(f'Collected comments from video {video_count} ({video_id})')
        except Exception as e:
            print(f'An error occurred while processing video {video_id}: {str(e)}')
            continue
    
    next_page_token = search_response.get('nextPageToken')
    
    if not next_page_token:
        break

# Write comments to a CSV file
csv_filename = "youtube_gpt_comments.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(["Comment"])
    csv_writer.writerows([[comment] for comment in comments])

print(f"Comments from 1000 videos related to 'GPT' saved to '{csv_filename}'.")
# Out:
# Collected comments from video 1 (-4Oso9-9KTQ)
# Collected comments from video 2 (TpZcGhYp4rw)
# An error occurred while processing video bZQun8Y4L2A: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=bZQun8Y4L2A&maxResults=100&pageToken=&key=AIzaSyBgbUQ9jDaI5Icglxs9eJLdf9VKJ3BG0C4&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Collected comments from video 3 (C_78DM8fG6E)
# Collected comments from video 4 (PmO2YMKoXnc)
# Collected comments from video 5 (FPZONhA0C60)
# Collected comments from video 6 (DIU48QL5Cyk)
# Collected comments from video 7 (YCaCC8Lk9y8)
# Collected comments from video 8 (gF4ERbZ6-Jw)
# Collected comments from video 9 (L_Guz73e6fw)
# Collected comments from video 10 (vw-KWfKwvTQ)
# Collected comments from video 11 (O68y0yRZL1Y)
# Collected comments from video 12 (FF_HzfqxS2o)
# Collected comments from video 13 (ey1kHYVu19c)
# Collected comments from video 14 (gWy-pJ2ofEM)
# Collected comments from video 15 (RhcsYRQ5iGo)
# Collected comments from video 16 (8QZun3RlT7I)
# Collected comments from video 17 (RCBZ-Xj2dgQ)
# Collected comments from video 18 (3ao7Z8duDXc)
# Collected comments from video 19 (kCc8FmEb1nY)
# Collected comments from video 20 (Gaf_jCnA6mc)
# Collected comments from video 21 (tAGQY9_2Heo)
# Collected comments from video 22 (qbIk7-JPB2c)
# Collected comments from video 23 (JTxsNm9IdYU)
# Collected comments from video 24 (8Ln5C7xSXak)
# Collected comments from video 25 (vYvOTGk7hOA)
# Collected comments from video 26 (jO5Wev0nAjM)
# Collected comments from video 27 (4j0Ky_diI44)
# Collected comments from video 28 (9QXwJoDXA3E)
# Collected comments from video 29 (7t-ch8X2EeQ)
<HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=5OIkDviv9h0&maxResults=100&pageToken=&key=AIzaSyBgbUQ9jDaI5Icglxs9eJLdf9VKJ3BG0C4&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Collected comments from video 579 (ACENjAsFyIs)
# Collected comments from video 580 (2PMZo1fi85o)
# Collected comments from video 581 (tdTOHjsHcFU)
# Collected comments from video 582 (3nxIQ3zufhg)
# Collected comments from video 583 (BxKZyi5r-iI)
# Collected comments from video 584 (OOo6GmDJ2pg)
# Collected comments from video 585 (Gky-p1IIGbE)
# Collected comments from video 586 (CQWhhvFdzJE)
# Collected comments from video 587 (x3rFqawIym0)
# Collected comments from video 588 (ZHP8O4_FAlc)
# Collected comments from video 589 (X-zqu0pqYco)
# Collected comments from video 590 (OvdbB0uL-4M)
# Collected comments from video 591 (J3eXMtvuZzA)
# Collected comments from video 592 (DtG0regiqyI)
# Comments from 1000 videos related to 'GPT' saved to 'youtube_gpt_comments.csv'.

# %%
# Define your search query
search_query = 'GPT'

# Variables to keep track of videos, comments, and data
data = []
video_count = 0
next_page_token = None

# Continue fetching videos and data until 1000 comments are collected or no more videos are available
while video_count < 1000:
    # Perform a search for videos related to the query
    search_response = youtube.search().list(
        q=search_query,
        type='video',
        maxResults=50,  # Adjust the number of results per page
        pageToken=next_page_token if next_page_token else '',
        part='id'  # Only fetch video IDs to save quota
    ).execute()

    video_ids = [item['id']['videoId'] for item in search_response['items']]
    
    # Fetch data and comments from the videos
    for video_id in video_ids:
        try:
            # Fetch video details
            video_details = youtube.videos().list(
                part='snippet,statistics',
                id=video_id
            ).execute()
            
            snippet = video_details['items'][0]['snippet']
            statistics = video_details['items'][0]['statistics']
            
            video_title = snippet['title']
            view_count = statistics['viewCount'] if 'viewCount' in statistics else 0
            like_count = statistics['likeCount'] if 'likeCount' in statistics else 0
            dislike_count = statistics['dislikeCount'] if 'dislikeCount' in statistics else 0
            
            # Check if comments are disabled for this video
            if 'commentsDisabled' in snippet and snippet['commentsDisabled']:
                print(f'Comments are disabled for video {video_id}. Skipping...')
                continue
        
            # Fetch comments from the video
            video_comments = []
            video_next_page_token = None

            while True:
                comment_request = youtube.commentThreads().list(
                    part='snippet',
                    videoId=video_id,
                    maxResults=100,  # Adjust the number of comments per page
                    pageToken=video_next_page_token if video_next_page_token else ''
                )

                comment_response = comment_request.execute()

                for comment in comment_response['items']:
                    comment_text = comment['snippet']['topLevelComment']['snippet']['textDisplay']
                    data.append([video_title, view_count, like_count, dislike_count, comment_text])
                    # video_comments.append(comment_text)

                video_next_page_token = comment_response.get('nextPageToken')

                if not video_next_page_token:
                    break

            video_count += 1
            print(f'Collected data and comments for video {video_count} ({video_id})')
            
            # Add video data to the list
            # data.append([video_title, view_count, like_count, dislike_count, video_comments])
        except Exception as e:
            print(f'An error occurred while processing video {video_id}: {str(e)}')
            continue
    
    next_page_token = search_response.get('nextPageToken')
    
    if not next_page_token:
        break

# Write data to a CSV file
csv_filename = "youtube_gpt_video_data.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(["Video Title", "View Count", "Like Count", "Dislike Count", "Comments"])
    csv_writer.writerows(data)

print(f"Video data and comments from 1000 videos related to 'GPT' saved to '{csv_filename}'.")
# Out:
# Collected data and comments for video 1 (-4Oso9-9KTQ)
# Collected data and comments for video 2 (TpZcGhYp4rw)
# An error occurred while processing video bZQun8Y4L2A: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=bZQun8Y4L2A&maxResults=100&pageToken=&key=AIzaSyB1pKjN7q4_5Is-QCFf2Ui23qxhJhwLIiQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Collected data and comments for video 3 (PmO2YMKoXnc)
# Collected data and comments for video 4 (C_78DM8fG6E)
# Collected data and comments for video 5 (vw-KWfKwvTQ)
# Collected data and comments for video 6 (YCaCC8Lk9y8)
# Collected data and comments for video 7 (DIU48QL5Cyk)
# Collected data and comments for video 8 (mXQ1KVES_Xc)
# Collected data and comments for video 9 (L_Guz73e6fw)
# Collected data and comments for video 10 (FPZONhA0C60)
# Collected data and comments for video 11 (ey1kHYVu19c)
# Collected data and comments for video 12 (RCBZ-Xj2dgQ)
# Collected data and comments for video 13 (Gaf_jCnA6mc)
# Collected data and comments for video 14 (FF_HzfqxS2o)
# Collected data and comments for video 15 (p6Yw0Bx5dbw)
# Collected data and comments for video 16 (gWy-pJ2ofEM)
# Collected data and comments for video 17 (JTxsNm9IdYU)
# Collected data and comments for video 18 (RhcsYRQ5iGo)
# Collected data and comments for video 19 (3ao7Z8duDXc)
# Collected data and comments for video 20 (kCc8FmEb1nY)
# Collected data and comments for video 21 (O68y0yRZL1Y)
# Collected data and comments for video 22 (qbIk7-JPB2c)
# Collected data and comments for video 23 (8QZun3RlT7I)
# Collected data and comments for video 24 (tAGQY9_2Heo)
# Collected data and comments for video 25 (vYvOTGk7hOA)
# Collected data and comments for video 26 (IrD_MqPUkKk)
# Collected data and comments for video 27 (Fjh1kwOzr7c)
# Collected data and comments for video 28 (jO5Wev0nAjM)
# Collected data and comments for video 29 (7t-ch8X2EeQ)
# Collected data and comments for video 30 (4j0Ky_diI44)
# Collected data and comments for video 31 (8Ln5C7xSXak)
# Collected data and comments for video 32 (9QXwJoDXA3E)
# Collected data and comments for video 33 (wVzuvf9D9BU)
# Collected data and comments for video 34 (0lOSvOoF2to)
# Collected data and comments for video 35 (DXWwCggFROk)
# Collected data and comments for video 36 (3IweGfgytgY)
# Collected data and comments for video 37 (xyz31KBxFes)
# Collected data and comments for video 38 (QA6Wua_lyvw)
# Collected data and comments for video 39 (O8GUH0_htRM)
# Collected data and comments for video 40 (o5MutYFWsM8)
# Collected data and comments for video 41 (TJbqLD3UV5Y)
# Collected data and comments for video 42 (Zgk9-aTJ--o)
# An error occurred while processing video --khbXchTeE: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=--khbXchTeE&maxResults=100&pageToken=&key=AIzaSyB1pKjN7q4_5Is-QCFf2Ui23qxhJhwLIiQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Collected data and comments for video 43 (dz4H5epsHkY)
# Collected data and comments for video 44 (x6bZOjzfCqo)
# Collected data and comments for video 45 (2Pd0YExeC5o)
# Collected data and comments for video 46 (ZqhJVw1hYWQ)
# Collected data and comments for video 47 (kod8ntKBEB8)
# Collected data and comments for video 48 (OaO3_x0nHPY)
# Collected data and comments for video 49 (6NoTuqDAkfg)
# Collected data and comments for video 50 (SglBO5f7j8U)
# Collected data and comments for video 51 (bSvTVREwSNw)
# Collected data and comments for video 52 (FzeGG0NuLKU)
# Collected data and comments for video 53 (SZorAJ4I-sA)
# Collected data and comments for video 54 (yaEjUTmmo6U)
# Collected data and comments for video 55 (nrC07M2XV1I)
# Collected data and comments for video 56 (hX0OUFJs9nQ)
# Collected data and comments for video 57 (Genj8-NcmBo)
# Collected data and comments for video 58 (KCqvIlr9UJU)
# Collected data and comments for video 59 (GCwEIvzxPSc)
# Collected data and comments for video 60 (9RH5xXTeD_U)
# Collected data and comments for video 61 (9AXP7tCI9PI)
# Collected data and comments for video 62 (TOLSWQx9qMw)
# Collected data and comments for video 63 (5SgJKZLBrmg)
# Collected data and comments for video 64 (TkxroMCmpDw)
# Collected data and comments for video 65 (nnJSVgDftVk)
# Collected data and comments for video 66 (Blrqe-qBVec)
# Collected data and comments for video 67 (i1VqqX4iAZ0)
# Collected data and comments for video 68 (LTGx1CWcrpo)
# Collected data and comments for video 69 (lhMycKP_0tI)
# Collected data and comments for video 70 (j02OZRjf2d8)
# Collected data and comments for video 71 (HOLgWHSiEpM)
# Collected data and comments for video 72 (0RzDwyq7lsQ)
# Collected data and comments for video 73 (7hztoCMVo0U)
# Collected data and comments for video 74 (ab6xJ4E23VQ)
# Collected data and comments for video 75 (1zx7TSzylIs)
# Collected data and comments for video 76 (VK5mm8JUUJQ)
# Collected data and comments for video 77 (hVade_8H8mE)
# Collected data and comments for video 78 (YgGUGlRVn-U)
# Collected data and comments for video 79 (kbL35usE8L0)
# Collected data and comments for video 80 (aNMjK3Lh6Dg)
# Collected data and comments for video 81 (8j2opqhGwmw)
# Collected data and comments for video 82 (3efMy9qf5Jg)
# Collected data and comments for video 83 (FnY34vXIMsM)
# Collected data and comments for video 84 (ButSJrf1AIY)
# Collected data and comments for video 85 (wiQOZwbQ0pk)
# Collected data and comments for video 86 (ucp49z5pQ2s)
# Collected data and comments for video 87 (jHv63Uvk5VA)
# Collected data and comments for video 88 (DzDghs79Cy0)
# Collected data and comments for video 89 (UBy6lQHIY0Y)
# Collected data and comments for video 90 (ceMuK0xUtSY)
# Collected data and comments for video 91 (wwkqOq5g_XM)
# Collected data and comments for video 92 (7oZKIwz2wk8)
# Collected data and comments for video 93 (KrzJVu2D5BU)
# Collected data and comments for video 94 (O9Y_ZdsuKWQ)
# Collected data and comments for video 95 (BntGOaMrB90)
# Collected data and comments for video 96 (naKZNta1fSs)
# Collected data and comments for video 97 (Tb-nVUbKWdc)
# Collected data and comments for video 98 (Rog9oHtVmjM)
# Collected data and comments for video 99 (YgGUGlRVn-U)
# Collected data and comments for video 100 (29TUSWFY5Ok)
# Collected data and comments for video 101 (zzQBgnLtKqQ)
# Collected data and comments for video 102 (ucp49z5pQ2s)
# Collected data and comments for video 103 (ivexBzomPv4)
# Collected data and comments for video 104 (82Q6yu_xZVA)
# Collected data and comments for video 105 (ButSJrf1AIY)
# Collected data and comments for video 106 (KrzJVu2D5BU)
# Collected data and comments for video 107 (IZDPHYMUCk4)
# Collected data and comments for video 108 (VuHNlPy5_Qk)
# Collected data and comments for video 109 (XPSyoK68_Fo)
# Collected data and comments for video 110 (Rog9oHtVmjM)
# Collected data and comments for video 111 (zqSJG39HQoM)
# Collected data and comments for video 112 (kBbv2_9vcC0)
# Collected data and comments for video 113 (0-i5YUF3ep4)
# Collected data and comments for video 114 (jHv63Uvk5VA)
# Collected data and comments for video 115 (naKZNta1fSs)
# Collected data and comments for video 116 (lPfb0-j-0tU)
# Collected data and comments for video 117 (QYVfHK8_Wu0)
# Collected data and comments for video 118 (gyeiL1JZnXc)
# Collected data and comments for video 119 (_XDt3zzKF0Q)
# Collected data and comments for video 120 (J75rx8ncJwk)
# Collected data and comments for video 121 (cD_Xt1F3uKg)
# Collected data and comments for video 122 (JyVH4FbSwFo)
# Collected data and comments for video 123 (ka1Pqk2o3tM)
# Collected data and comments for video 124 (BntGOaMrB90)
# Collected data and comments for video 125 (BPx6u7GM2rA)
# Collected data and comments for video 126 (3XJkTzu-z7k)
# Collected data and comments for video 127 (HJeL7BWjSRk)
# Collected data and comments for video 128 (0fq1jlWcUv8)
# Collected data and comments for video 129 (ZVM2c6GK7SA)
# Collected data and comments for video 130 (thMU9t6nxaw)
# Collected data and comments for video 131 (7ell8KEbhJo)
# Collected data and comments for video 132 (6r_OgPtIae8)
# Collected data and comments for video 133 (NiDat36IyF8)
# Collected data and comments for video 134 (5Qh5ENgvr0M)
# Collected data and comments for video 135 (zxZjap-IpG8)
# Collected data and comments for video 136 (dNrTrx42DGQ)
# Collected data and comments for video 137 (RRnThAtKuq0)
# Collected data and comments for video 138 (DMFA0xKcSw4)
# Collected data and comments for video 139 (6-bxs8xtWeQ)
# Collected data and comments for video 140 (Q07rFZtc2Ao)
# Collected data and comments for video 141 (8ouk1gBvSM0)
# Collected data and comments for video 142 (En6KVC_1FAQ)
# Collected data and comments for video 143 (LqjVMy2qhRY)
# Collected data and comments for video 144 (m6K3XTFdaHE)
# Collected data and comments for video 145 (nVC9D9fRyNU)
# Collected data and comments for video 146 (m2UzT_5beko)
# Collected data and comments for video 147 (AzVhMUujzCk)
# Collected data and comments for video 148 (dJU7jrKtCpc)
# Collected data and comments for video 149 (AzVhMUujzCk)
# Collected data and comments for video 150 (Wkp0ltIeoJQ)
# Collected data and comments for video 151 (5KiEG92wpjw)
# Collected data and comments for video 152 (2IhOiQSVo7s)
# Collected data and comments for video 153 (Genj8-NcmBo)
# Collected data and comments for video 154 (t70Bl3w7bxY)
# Collected data and comments for video 155 (axvZJswmolM)
# Collected data and comments for video 156 (Aaaf6CzG_3Y)
# Collected data and comments for video 157 (RdAQnkDzGvc)
# Collected data and comments for video 158 (7JWMYd038QI)
# Collected data and comments for video 159 (V0A7B0PmNb8)
# Collected data and comments for video 160 (wzwAFRaKsB8)
# Collected data and comments for video 161 (UlfaxDxPUWI)
# Collected data and comments for video 162 (w4orK3jFPeY)
# Collected data and comments for video 163 (u_dSUtp4eM8)
# Collected data and comments for video 164 (Ph-e3klU6KE)
# Collected data and comments for video 165 (Gn3vuzSSxLE)
# Collected data and comments for video 166 (aXx43zabqGM)
# Collected data and comments for video 167 (y9Gi3UgNA3E)
# Collected data and comments for video 168 (AXn2XVLf7d0)
# Collected data and comments for video 169 (ertZm0lOmU4)
# Collected data and comments for video 170 (sNnJJZbpCEs)
# Collected data and comments for video 171 (K0SZ9mdygTw)
# Collected data and comments for video 172 (hNA685AihMk)
# Collected data and comments for video 173 (_7f9aFDEOzw)
# Collected data and comments for video 174 (-IBxIXBaei8)
# Collected data and comments for video 175 (Hm9kDl6J1_s)
# Collected data and comments for video 176 (-QwfDgaStEM)
# Collected data and comments for video 177 (EUHIvccehUc)
# Collected data and comments for video 178 (_LghCCRGLsM)
# Collected data and comments for video 179 (h6tYRjE92gA)
# Collected data and comments for video 180 (O4EmRi0_CI4)
# Collected data and comments for video 181 (-DYESHvB5uQ)
# Collected data and comments for video 182 (5zhvwDWbxag)
# Collected data and comments for video 183 (CxYclUqhiA8)
# Collected data and comments for video 184 (ZClAe1hxRHo)
# Collected data and comments for video 185 (GKgcXbtpvxU)
# Collected data and comments for video 186 (Dp7QoCK7XMg)
# Collected data and comments for video 187 (wH2sLoha0S8)
# Collected data and comments for video 188 (BoVcWL9hnVw)
# Collected data and comments for video 189 (b7q5zZ46ZYs)
# Collected data and comments for video 190 (8kwWLDUwEPY)
# Collected data and comments for video 191 (lqvZxkBXAXw)
# Collected data and comments for video 192 (Bxy7I_vtyf8)
# Collected data and comments for video 193 (eX709PWKias)
# Collected data and comments for video 194 (_BvibtDzc1s)
# Collected data and comments for video 195 (Coj72EzmX20)
# Collected data and comments for video 196 (FdZ8LKiJBhQ)
# Collected data and comments for video 197 (1EjWQjaY_qI)
# Collected data and comments for video 198 (sGYWQiU7C70)
# Collected data and comments for video 199 (fzUhO3-iuf0)
# Collected data and comments for video 200 (_BvibtDzc1s)
# Collected data and comments for video 201 (TwMu4NnRqwg)
# Collected data and comments for video 202 (mZdDnCnaLOA)
# Collected data and comments for video 203 (o2M_paJf48I)
# Collected data and comments for video 204 (B7Om_b4evdA)
# Collected data and comments for video 205 (fTyvGHRWZRY)
# Collected data and comments for video 206 (p3ByFcXK9-g)
# Collected data and comments for video 207 (hC-Z1-F5Pdo)
# Collected data and comments for video 208 (V3XcrVI3fL4)
# Collected data and comments for video 209 (EM25tJ4oHUM)
# Collected data and comments for video 210 (D7IOdWpTq5A)
# Collected data and comments for video 211 (Bxy7I_vtyf8)
# Collected data and comments for video 212 (h9lTRqKfKs0)
# Collected data and comments for video 213 (f2eZ5sGdOaI)
# Collected data and comments for video 214 (pqtx80aFiNk)
# Collected data and comments for video 215 (Nc2D-gCoruU)
# Collected data and comments for video 216 (R9Sdu-KEFYo)
# Collected data and comments for video 217 (pJJh2gF8-J8)
# Collected data and comments for video 218 (ovKnEWx-vyA)
# Collected data and comments for video 219 (Rn1jbv1qo0E)
# Collected data and comments for video 220 (s4w5mGQVxjU)
# Collected data and comments for video 221 (IADFe10SbY4)
# Collected data and comments for video 222 (sL1BNTU-4PI)
# Collected data and comments for video 223 (RP4E_9YoUNA)
# Collected data and comments for video 224 (JgXMxPKUvao)
# Collected data and comments for video 225 (xAUuLECuyd0)
# Collected data and comments for video 226 (Ix9WIZpArm0)
# Collected data and comments for video 227 (_7f9aFDEOzw)
# Collected data and comments for video 228 (0EGezRVeqx0)
# Collected data and comments for video 229 (J9QVLuvzIb8)
# Collected data and comments for video 230 (SyRD5Z03r04)
# Collected data and comments for video 231 (MdJ0E6_05ok)
# Collected data and comments for video 232 (KCqvIlr9UJU)
# Collected data and comments for video 233 (9N1Hu0YJ-ZE)
# Collected data and comments for video 234 (AB8RiWSO1iw)
# Collected data and comments for video 235 (LN3783F4DZw)
# Collected data and comments for video 236 (7xFjGyiNBLE)
# Collected data and comments for video 237 (C4unsrZ9QPg)
# Collected data and comments for video 238 (jb3Qxi9U4P4)
# Collected data and comments for video 239 (ENaJ58gi020)
# Collected data and comments for video 240 (V25O66DOU8Y)
# Collected data and comments for video 241 (yR27J-QUx2o)
# Collected data and comments for video 242 (nY234RoQeHw)
# Collected data and comments for video 243 (ZurB5PNuDQs)
# Collected data and comments for video 244 (zpRM25pUD8w)
# Collected data and comments for video 245 (klomQzDf_iE)
# Collected data and comments for video 246 (vM69BMxKhZs)
# Collected data and comments for video 247 (UXHQibz2-rw)
# Collected data and comments for video 248 (5cboTIvE4Nk)
# Collected data and comments for video 249 (klomQzDf_iE)
# Collected data and comments for video 250 (vM69BMxKhZs)
# Collected data and comments for video 251 (5cboTIvE4Nk)
# Collected data and comments for video 252 (jbOEM26B9T8)
# Collected data and comments for video 253 (0Xos8e3iF4A)
# Collected data and comments for video 254 (7MeHry2pglw)
# Collected data and comments for video 255 (6ULDRk5nzPQ)
# Collected data and comments for video 256 (KPrrq7VRdZU)
# Collected data and comments for video 257 (ByV5w1ES38A)
# Collected data and comments for video 258 (iarXRwwa16I)
# Collected data and comments for video 259 (fLYHCGF6qt8)
# Collected data and comments for video 260 (qGQ33oXyYvw)
# Collected data and comments for video 261 (iz6jDyyRVtA)
# Collected data and comments for video 262 (MwlKlC2gBSs)
# Collected data and comments for video 263 (LK0LZzb5PCE)
# Collected data and comments for video 264 (EE6IklU2lHk)
# Collected data and comments for video 265 (DPfNhPWb-5g)
# Collected data and comments for video 266 (t4KnAJJojXQ)
# Collected data and comments for video 267 (yUszJyS3d7A)
# Collected data and comments for video 268 (hm-bt3CGFSY)
# Collected data and comments for video 269 (dGymR_mY0ys)
# Collected data and comments for video 270 (ivexBzomPv4)
# Collected data and comments for video 271 (Mqg3aTGNxZ0)
# Collected data and comments for video 272 (q1vkQEYB6kw)
# Collected data and comments for video 273 (_QERfac0uug)
# Collected data and comments for video 274 (OeePmGqL7Ew)
# Collected data and comments for video 275 (jtn_-Z8b5h8)
# Collected data and comments for video 276 (0wzz_QR4JeA)
# Collected data and comments for video 277 (yyka3pKImYw)
# Collected data and comments for video 278 (outcGtbnMuQ)
# Collected data and comments for video 279 (7oZKIwz2wk8)
# Collected data and comments for video 280 (_B2aWE2DSiY)
# Collected data and comments for video 281 (NXClSwN_GZY)
# Collected data and comments for video 282 (xY42vbH_zCw)
# Collected data and comments for video 283 (xqG0TF0cnB0)
# Collected data and comments for video 284 (mWZBVz_Ki-o)
# Collected data and comments for video 285 (RR_1zwGdgIU)
# Collected data and comments for video 286 (d8j20fubAj8)
# Collected data and comments for video 287 (WI5TyGrXG1k)
# Collected data and comments for video 288 (3ANjeVI8j38)
# Collected data and comments for video 289 (MzrYDkGTCrk)
# Collected data and comments for video 290 (o_Wl29aW5XM)
# Collected data and comments for video 291 (1n0wnf-r8E4)
# Collected data and comments for video 292 (xwEmARmzheE)
# Collected data and comments for video 293 (4SgYPcVtP_g)
# Collected data and comments for video 294 (F3ZlQ9vKuvg)
# Collected data and comments for video 295 (vyhmNV3bZdQ)
# Collected data and comments for video 296 (urSlJjEAsPY)
# Collected data and comments for video 297 (x77oE3TpUGk)
# Collected data and comments for video 298 (daTaIXmCzzo)
# Collected data and comments for video 299 (NXClSwN_GZY)
# Collected data and comments for video 300 (_QERfac0uug)
# Collected data and comments for video 301 (0_FzNqcXK_w)
# Collected data and comments for video 302 (nnJSVgDftVk)
# Collected data and comments for video 303 (eqIw6RrT8Ww)
# Collected data and comments for video 304 (ApyrVDBVx00)
# Collected data and comments for video 305 (9_MbW9FK1fA)
# Collected data and comments for video 306 (3ANjeVI8j38)
# Collected data and comments for video 307 (eMh51ews9-c)
# Collected data and comments for video 308 (nY234RoQeHw)
# Collected data and comments for video 309 (_qkS-k4E1Wg)
# Collected data and comments for video 310 (816nNmn0124)
# Collected data and comments for video 311 (pbbKJVDm4L8)
# Collected data and comments for video 312 (uhyc9-JQNzw)
# Collected data and comments for video 313 (MzrYDkGTCrk)
# Collected data and comments for video 314 (f_WcU_IdMGk)
# Collected data and comments for video 315 (AB8RiWSO1iw)
# Collected data and comments for video 316 (JSCJbBFXwiQ)
# Collected data and comments for video 317 (FzeGG0NuLKU)
# Collected data and comments for video 318 (4bq4KSVLm2g)
# Collected data and comments for video 319 (Ax54ere3F5E)
# Collected data and comments for video 320 (MQk-0XqfdNs)
# Collected data and comments for video 321 (biS8G8x8DdA)
# Collected data and comments for video 322 (_LghCCRGLsM)
# Collected data and comments for video 323 (r5ioP-v4pRs)
# Collected data and comments for video 324 (ek_yX-mKT7k)
# Collected data and comments for video 325 (QlVG0i19BwI)
# An error occurred while processing video R0ai9XpdZ5M: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=R0ai9XpdZ5M&maxResults=100&pageToken=&key=AIzaSyB1pKjN7q4_5Is-QCFf2Ui23qxhJhwLIiQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Collected data and comments for video 326 (drdvhSEzOns)
# Collected data and comments for video 327 (D7IOdWpTq5A)
# Collected data and comments for video 328 (ZClAe1hxRHo)
# Collected data and comments for video 329 (Wn9Hzjmi03Q)
# Collected data and comments for video 330 (1b2pH0wWXJQ)
# Collected data and comments for video 331 (ka1Pqk2o3tM)
# Collected data and comments for video 332 (3gMqL72iuS0)
# Collected data and comments for video 333 (gjpHQKy3TUY)
# Collected data and comments for video 334 (HJeL7BWjSRk)
# Collected data and comments for video 335 (_7f9aFDEOzw)
# Collected data and comments for video 336 (DPfNhPWb-5g)
# Collected data and comments for video 337 (Cfl4se94DB0)
# Collected data and comments for video 338 (efcMQcYaHsw)
# Collected data and comments for video 339 (ZFwRDh_2qqg)
# Collected data and comments for video 340 (6c8ssb7agko)
# Collected data and comments for video 341 (hJP5GqnTrNo)
# Collected data and comments for video 342 (ovKnEWx-vyA)
# Collected data and comments for video 343 (LN3783F4DZw)
# Collected data and comments for video 344 (GV3Z0ecU0wQ)
# Collected data and comments for video 345 (5hs9CJQZ5LQ)
# Collected data and comments for video 346 (yR27J-QUx2o)
# Collected data and comments for video 347 (AbjSHNrlvXM)
# Collected data and comments for video 348 (wDXPXgn5hX4)
# Collected data and comments for video 349 (VIJI9FRk0s8)
# Collected data and comments for video 350 (SIRMboPpHo8)
# Collected data and comments for video 351 (qOTFhw_OwQY)
# Collected data and comments for video 352 (DzDghs79Cy0)
# Collected data and comments for video 353 (Q0HKGCUH1DA)
# Collected data and comments for video 354 (GtgQi1uca-E)
# Collected data and comments for video 355 (Q-w9cCjW0To)
# Collected data and comments for video 356 (4f6U12OX6eo)
# Collected data and comments for video 357 (TzhnMKlJ8H4)
# Collected data and comments for video 358 (IqivoyIbdJM)
# Collected data and comments for video 359 (WizoCwjEKsg)
# Collected data and comments for video 360 (VVfFf_XW8zw)
# Collected data and comments for video 361 (r6zbLfffLns)
# Collected data and comments for video 362 (gDxzWh_oVbg)
# Collected data and comments for video 363 (iqRMltMhJ0I)
# Collected data and comments for video 364 (0nT5XQbp1N0)
# Collected data and comments for video 365 (9rtv25Zfcu0)
# Collected data and comments for video 366 (h6sMZCeBAcY)
# Collected data and comments for video 367 (M56AQ3mKHDM)
# Collected data and comments for video 368 (SVh3F8MLCmg)
# Collected data and comments for video 369 (CIest6983OA)
# Collected data and comments for video 370 (GNUTZ8Punyw)
# Collected data and comments for video 371 (aUYVsv5yqcg)
# Collected data and comments for video 372 (LK0LZzb5PCE)
# Collected data and comments for video 373 (ButSJrf1AIY)
# Collected data and comments for video 374 (EUHIvccehUc)
# Collected data and comments for video 375 (0Xos8e3iF4A)
# Collected data and comments for video 376 (-WGHCGsaKKU)
# Collected data and comments for video 377 (jkSSoy39VrU)
# Collected data and comments for video 378 (ntACspNRNXk)
# Collected data and comments for video 379 (lDuXl8rLAZg)
# Collected data and comments for video 380 (BJTaHEvXafE)
# Collected data and comments for video 381 (zzPwTJGBLOc)
# Collected data and comments for video 382 (gKmawmUw7Jo)
# Collected data and comments for video 383 (CHzNNxZOIYI)
# Collected data and comments for video 384 (3fef9V97VEo)
# Collected data and comments for video 385 (2hajzPYNo00)
# Collected data and comments for video 386 (hJP5GqnTrNo)
# Collected data and comments for video 387 (BzPA7WHHkDI)
# Collected data and comments for video 388 (MO7bazLe46c)
# Collected data and comments for video 389 (4KeNU4Kzlxg)
# Collected data and comments for video 390 (OM27I6lUeGQ)
# Collected data and comments for video 391 (enfW32iBDb8)
# Collected data and comments for video 392 (Cfl4se94DB0)
# Collected data and comments for video 393 (J6bS3YX217k)
# Collected data and comments for video 394 (2vg6r3rlZGQ)
# Collected data and comments for video 395 (sKrT6mBrosc)
# Collected data and comments for video 396 (WO5uBTIebYI)
# Collected data and comments for video 397 (xF_7k4neE-c)
# Collected data and comments for video 398 (WO5uBTIebYI)
# Collected data and comments for video 399 (2vg6r3rlZGQ)
# Collected data and comments for video 400 (wq9BfOvqrSM)
# Collected data and comments for video 401 (xF_7k4neE-c)
# Collected data and comments for video 402 (SQonyxVcdSo)
# Collected data and comments for video 403 (k2mIlUjmHds)
# Collected data and comments for video 404 (8RfZhLVYxxU)
# Collected data and comments for video 405 (kQY5ileSS5c)
# Collected data and comments for video 406 (p8zgZtrCyo0)
# Collected data and comments for video 407 (dSLAGkhkrKQ)
# Collected data and comments for video 408 (x77oE3TpUGk)
# Collected data and comments for video 409 (eodSrSZmGgE)
# Collected data and comments for video 410 (1b2pH0wWXJQ)
# Collected data and comments for video 411 (0UW5AncU5e8)
# Collected data and comments for video 412 (TfNiCeN7Zvo)
# Collected data and comments for video 413 (mYNqikThZvQ)
# Collected data and comments for video 414 (ek_yX-mKT7k)
# Collected data and comments for video 415 (oCDo_9ItWew)
# Collected data and comments for video 416 (l-CjXFmcVzY)
# An error occurred while processing video R0ai9XpdZ5M: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=R0ai9XpdZ5M&maxResults=100&pageToken=&key=AIzaSyB1pKjN7q4_5Is-QCFf2Ui23qxhJhwLIiQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Collected data and comments for video 417 (1Vm-gbiGOT8)
# Collected data and comments for video 418 (wg4g7f01LpE)
# Collected data and comments for video 419 (Ob2L9ytM4S4)
# Collected data and comments for video 420 (JwtKAspJRzA)
# Collected data and comments for video 421 (VxKfDcZ_24s)
# Collected data and comments for video 422 (_Vv5m2Z5nns)
# Collected data and comments for video 423 (slmYSl_F2R0)
# Collected data and comments for video 424 (jUluHJrqaY8)
# Collected data and comments for video 425 (cq3bEZG6RXs)
# Collected data and comments for video 426 (Z2sQmT5Hx24)
# Collected data and comments for video 427 (biS8G8x8DdA)
# Collected data and comments for video 428 (4bq4KSVLm2g)
# Collected data and comments for video 429 (oNA4q9e1wEc)
# Collected data and comments for video 430 (1991JzurRlk)
# Collected data and comments for video 431 (NGpzej5-BPI)
# Collected data and comments for video 432 (uhyc9-JQNzw)
# Collected data and comments for video 433 (8fjNT33UfK4)
# Collected data and comments for video 434 (IbzrJJAVjV8)
# Collected data and comments for video 435 (62Y6zG2tLNI)
# Collected data and comments for video 436 (cdb-UD_MbKQ)
# Collected data and comments for video 437 (L6EJ1lTXQF0)
# Collected data and comments for video 438 (hgm4anaM944)
# Collected data and comments for video 439 (8NELQojJw_U)
# Collected data and comments for video 440 (J3Ht-xuvUis)
# Collected data and comments for video 441 (jHfCeiVwZV8)
# Collected data and comments for video 442 (sze2SZwIEuE)
# Collected data and comments for video 443 (tzE-BWEO8MY)
# Collected data and comments for video 444 (4MeSamcIW0A)
# Collected data and comments for video 445 (z43eC9ZaAM8)
# Collected data and comments for video 446 (M7xgHFjWOKE)
# Collected data and comments for video 447 (oZdsvQaLT1U)
# Collected data and comments for video 448 (Xw-zxQSEzqo)
# Collected data and comments for video 449 (0wCjosz1vOA)
# Collected data and comments for video 450 (qkyw3mis9Io)
# Collected data and comments for video 451 (QlVG0i19BwI)
# Collected data and comments for video 452 (gS388zAIweo)
# Collected data and comments for video 453 (HBojPl_tgcQ)
# Collected data and comments for video 454 (MlK6SIjcjE8)
# Collected data and comments for video 455 (q0aTyNCJM1o)
# Collected data and comments for video 456 (Eih3dWUaxHE)
# Collected data and comments for video 457 (d_aYyw4RDZw)
# Collected data and comments for video 458 (15qXUHjXLrg)
# Collected data and comments for video 459 (Ygs46Sb6hDw)
# Collected data and comments for video 460 (zcn7uOAx4pQ)
# Collected data and comments for video 461 (jM4PcoX83Eo)
# Collected data and comments for video 462 (WJoMZLI1oZU)
# Collected data and comments for video 463 (3tE2LJ7BWys)
# Collected data and comments for video 464 (I_ArKQJZLqg)
# Collected data and comments for video 465 (FUcNXG1uxV0)
# Collected data and comments for video 466 (43FtiXq7OvQ)
# Collected data and comments for video 467 (p2Cqq6XLjsk)
# Collected data and comments for video 468 (GbtPyqFCT8M)
# Collected data and comments for video 469 (KQ3fYFquus4)
# Collected data and comments for video 470 (50lW2pz6MCc)
# Collected data and comments for video 471 (5rBVZY30e-w)
# Collected data and comments for video 472 (q8KaTlw6ijg)
# Collected data and comments for video 473 (f81qKAJUdKc)
# Collected data and comments for video 474 (Dvx2Xnf0z-M)
# Collected data and comments for video 475 (jgHhhjIE_3c)
# Collected data and comments for video 476 (rl1OE9dpzN0)
# Collected data and comments for video 477 (TIppE90B5_Y)
# Collected data and comments for video 478 (jolB9qMu-dc)
# Collected data and comments for video 479 (nff13Rpsq9k)
# Collected data and comments for video 480 (hc04PLWPRCQ)
# Collected data and comments for video 481 (IyKKhxYJ4U4)
# Collected data and comments for video 482 (DlYyDyuWE7w)
# Collected data and comments for video 483 (t50yMuVpZzs)
# Collected data and comments for video 484 (KBtqhD1lTTg)
# Collected data and comments for video 485 (sYKefDf--Rg)
# Collected data and comments for video 486 (zkN3-D9lX2w)
# Collected data and comments for video 487 (QIN6l9wWhWU)
# Collected data and comments for video 488 (PiwHeJRiCe8)
# Collected data and comments for video 489 (pmgoXz4s_zU)
# Collected data and comments for video 490 (QInmNthQT9Y)
# Collected data and comments for video 491 (olCkEzJv2YM)
# Collected data and comments for video 492 (9PzaIvMUreI)
# Collected data and comments for video 493 (BzEjA4JZFjk)
# Collected data and comments for video 494 (xSlOY4cNq-4)
# Collected data and comments for video 495 (cuhX4IkbAZY)
# Collected data and comments for video 496 (RYLnnuc2z_g)
# Collected data and comments for video 497 (cuhX4IkbAZY)
# Collected data and comments for video 498 (RYLnnuc2z_g)
# Collected data and comments for video 499 (tmEnYL4KhLo)
# Collected data and comments for video 500 (1IwQfCK46_c)
# Collected data and comments for video 501 (aUFIx5Xn5Ko)
# Collected data and comments for video 502 (OgYQAS9LY3o)
# Collected data and comments for video 503 (TKqSKUeJMAQ)
# Collected data and comments for video 504 (V9rkS8XoJn4)
# Collected data and comments for video 505 (0Bkc9mzd0yo)
# Collected data and comments for video 506 (DyFHKuYqe8g)
# Collected data and comments for video 507 (3Ac9CiELd5s)
# Collected data and comments for video 508 (NaurlNNPKEQ)
# Collected data and comments for video 509 (p3SU6sDihrU)
# Collected data and comments for video 510 (JzWDGH0ktyk)
# Collected data and comments for video 511 (8svhs4kIpyo)
# Collected data and comments for video 512 (gF4ERbZ6-Jw)
# Collected data and comments for video 513 (csRdVRQ3kbs)
# Collected data and comments for video 514 (6MSr21D6EK4)
# Collected data and comments for video 515 (evtydVu7Sdg)
# Collected data and comments for video 516 (ABHz5oZx-WA)
# Collected data and comments for video 517 (8EUbpwkPIL4)
# Collected data and comments for video 518 (SgiSBiZdufY)
# Collected data and comments for video 519 (rQvBOBSE__c)
# Collected data and comments for video 520 (G6mvcdy3KTs)
# Collected data and comments for video 521 (wEzt8ZIjTZ0)
# Collected data and comments for video 522 (rL3Vhq6c-CI)
# Collected data and comments for video 523 (ZJKqrlP3H4E)
# Collected data and comments for video 524 (jyFw7ZPXpME)
# Collected data and comments for video 525 (-MHm8YqWr3Y)
# Collected data and comments for video 526 (DuGcYHLNPHo)
# Collected data and comments for video 527 (tOO6lrj5Ir0)
# Collected data and comments for video 528 (t886ttwPsok)
# Collected data and comments for video 529 (nnZyqSZMj1c)
# Collected data and comments for video 530 (qjLfKMl7RME)
# Collected data and comments for video 531 (o1MtViQkcvQ)
# Collected data and comments for video 532 (fagNSXBqCV4)
# Collected data and comments for video 533 (sCAVyBqeWgs)
# Collected data and comments for video 534 (UkocG0Hi5Zk)
# Collected data and comments for video 535 (kE5iFeHii5I)
# Collected data and comments for video 536 (brBodKLGwjI)
# Collected data and comments for video 537 (7AWWKidyVhE)
# Collected data and comments for video 538 (1UKiGU6h7mE)
# Collected data and comments for video 539 (cH-DesY_9wQ)
# Collected data and comments for video 540 (yUugRx4ETDY)
# Collected data and comments for video 541 (sN4IdjtFL9s)
# Collected data and comments for video 542 (D2ioCRNjEu8)
# Collected data and comments for video 543 (s4YpJF3Ahrk)
# Collected data and comments for video 544 (ItxbY1MfA58)
# Collected data and comments for video 545 (YZcRVMa27hg)
# Collected data and comments for video 546 (tPPrWXcmayo)
# Collected data and comments for video 547 (oC2TUqbwg-U)
# Collected data and comments for video 548 (EUHIvccehUc)
# Collected data and comments for video 549 (JrT_9QXCIz8)
# Collected data and comments for video 550 (yUugRx4ETDY)
# Collected data and comments for video 551 (D2ioCRNjEu8)
# Collected data and comments for video 552 (zbdYzt7TwyU)
# Collected data and comments for video 553 (RR_1zwGdgIU)
# Collected data and comments for video 554 (ItxbY1MfA58)
# Collected data and comments for video 555 (YZcRVMa27hg)
# Collected data and comments for video 556 (4kDuEDPEA2k)
# Collected data and comments for video 557 (IWm994t3gIE)
# Collected data and comments for video 558 (rFYoR8UFPgU)
# Collected data and comments for video 559 (KFetFRtAqx0)
# Collected data and comments for video 560 (6trEI3P1Odk)
# Collected data and comments for video 561 (QL26tPilJhI)
# Collected data and comments for video 562 (RrZNulBihow)
# Collected data and comments for video 563 (GE6i5WrMfBk)
# Collected data and comments for video 564 (BS5kzVY-bUo)
# Collected data and comments for video 565 (h5cqd60hAlc)
# Collected data and comments for video 566 (gCjaBaDqsmw)
# Collected data and comments for video 567 (cmcjrECYC14)
# An error occurred while processing video 5OIkDviv9h0: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=5OIkDviv9h0&maxResults=100&pageToken=&key=AIzaSyB1pKjN7q4_5Is-QCFf2Ui23qxhJhwLIiQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Collected data and comments for video 568 (4uI1jaMRqwo)
# Collected data and comments for video 569 (tdTOHjsHcFU)
# Collected data and comments for video 570 (onJdpjUfIYU)
# Collected data and comments for video 571 (Kf_Nqu83Qtk)
# An error occurred while processing video MA6dYFfnDxM: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=MA6dYFfnDxM&maxResults=100&pageToken=&key=AIzaSyB1pKjN7q4_5Is-QCFf2Ui23qxhJhwLIiQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Collected data and comments for video 572 (OOo6GmDJ2pg)
# Collected data and comments for video 573 (JGs9SNaZUtQ)
# Collected data and comments for video 574 (CQWhhvFdzJE)
# Collected data and comments for video 575 (Gky-p1IIGbE)
# Collected data and comments for video 576 (7RGOYFU1TP8)
# Collected data and comments for video 577 (ACENjAsFyIs)
# Collected data and comments for video 578 (QLS7rfqeijk)
# Collected data and comments for video 579 (3nxIQ3zufhg)
# Collected data and comments for video 580 (w_ICvc-nci0)
# Collected data and comments for video 581 (Fzr4nmF9nxQ)
# Collected data and comments for video 582 (WnwVVFUsytU)
# Collected data and comments for video 583 (BxKZyi5r-iI)
# Collected data and comments for video 584 (X-zqu0pqYco)
# Collected data and comments for video 585 (Ravk5hNtMpw)
# Collected data and comments for video 586 (OvdbB0uL-4M)
# Collected data and comments for video 587 (J3eXMtvuZzA)
# Collected data and comments for video 588 (DtG0regiqyI)
# Video data and comments from 1000 videos related to 'GPT' saved to 'youtube_gpt_video_data.csv'.
